# %% [markdown]
# import dolfin

# %%
try:
  from dolfin import *
except ImportError: 
  # !wget "https://fem-on-colab.github.io/releases/fenics-install.sh" -O "/tmp/fenics-install.sh" && bash "/tmp/fenics-install.sh" 
  import dolfin
# Out:
# --2021-12-09 11:43:35--  https://fem-on-colab.github.io/releases/fenics-install.sh
# Resolving fem-on-colab.github.io (fem-on-colab.github.io)... 185.199.108.153, 185.199.109.153, 185.199.110.153, ...
# Connecting to fem-on-colab.github.io (fem-on-colab.github.io)|185.199.108.153|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1946 (1.9K) [application/x-sh]
# Saving to: ‘/tmp/fenics-install.sh’
#
# /tmp/fenics-install 100%[===================>]   1.90K  --.-KB/s    in 0s
#
# 2021-12-09 11:43:35 (23.7 MB/s) - ‘/tmp/fenics-install.sh’ saved [1946/1946]
#
# + PYBIND11_INSTALL_SCRIPT_PATH=https://fem-on-colab.github.io/releases/pybind11-install.sh
# + [[ https://fem-on-colab.github.io/releases/pybind11-install.sh == http* ]]
# + wget https://fem-on-colab.github.io/releases/pybind11-install.sh -O /tmp/pybind11-install.sh
# --2021-12-09 11:43:35--  https://fem-on-colab.github.io/releases/pybind11-install.sh
# ...

# %% [markdown]
# import corner detection algorithms

# %%
from google.colab import drive
drive.mount('/content/drive')
import sys
sys.path.append('/content/drive/MyDrive/mesh-parametrization-main')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from mesh_parametrization import mesh_deformation as md, cornerdetection_DoN as cd
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-3-1aa09a6b41a8> in <module>()
# ----> 1 from mesh_parametrization import mesh_deformation as md, cornerdetection_DoN as cd
#       2 import matplotlib.pyplot as plt
#       3 get_ipython().magic('matplotlib inline')
#
# ModuleNotFoundError: No module named 'mesh_parametrization'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %% [markdown]
# load mesh

# %%
mesh = md.read_mesh("LProfilTetMsh.xdmf")
display(mesh)

# %% [markdown]
# detect corners (output könnte vielleicht noch etwas schöner sein, vielleicht mit pandas dataframe)

# %%
cd.cornerdetection(mesh, "testoutput.txt", mode="angleSum", max_search_depth=2)

# %%
nodes, displacements = md.read_input_file("example_input.txt")

# %%
md.deform_mesh(mesh, nodes, displacements)
